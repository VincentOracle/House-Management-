# %%
#KMeans Clustering
# Machine learning applications of unsupervised learning include K-means clustering. 
# To divide a dataset into K clusters, where K is a predetermined number of clusters, 
# is the objective of k-means clustering.

# %%
#Importing the neccessary imports
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from collections import Counter
# %matplotlib inline

# %%
#Loading the dataset
data = pd.read_csv("C:\\Users\\n\\Downloads\\Country-data.csv")
data.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
data.tail()
# Out:
#        country  child_mort  exports  health  imports  income  inflation  \
# 162    Vanuatu        29.2     46.6    5.25     52.7    2950       2.62
# 163  Venezuela        17.1     28.5    4.91     17.6   16500      45.90
# 164    Vietnam        23.3     72.0    6.84     80.2    4490      12.10
# 165      Yemen        56.3     30.0    5.18     34.4    4480      23.60
# 166     Zambia        83.1     37.0    5.89     30.9    3280      14.00
#
#      life_expec  total_fer   gdpp
# 162        63.0       3.50   2970
# 163        75.4       2.47  13500
# 164        73.1       1.95   1310
# 165        67.5       4.67   1310
# 166        52.0       5.40   1460

# %%
data.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# 50%      5.390000   73.100000    2.410000    4660.000000
# 75%     10.750000   76.800000    3.880000   14050.000000
# max    104.000000   82.800000    7.490000  105000.000000

# %%
data.isna().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
#Correlation between features
#Using Pearson Correlation
plt.figure(figsize=(35,15))
cor = data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
# !pip install kneed
# Out:
# Requirement already satisfied: kneed in c:\users\n\anaconda3\lib\site-packages (0.8.2)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\n\anaconda3\lib\site-packages (from kneed) (1.21.5)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\n\anaconda3\lib\site-packages (from kneed) (1.7.3)

# %%
 # K-Means clustering
# Fit K-Means clustering algorithm with 3 clusters
#Importing the necessary libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Extract features to be used for clustering
data = pd.read_csv("C:\\Users\\n\\Downloads\\Country-data.csv")
X = data.drop([ 'country', 'gdpp'], axis=1)
# Standardize the data
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X_std)

# Assign clusters to each data point
data['Cluster'] = kmeans.labels_

# Print cluster centers
print(kmeans.cluster_centers_)
# Out:
# [[-0.33504767 -0.0755976  -0.49267018 -0.08470755 -0.29767044  0.10328209
#    0.19464825 -0.34430102]
#  [ 1.32661038 -0.42217389 -0.13954094 -0.15564827 -0.68923797  0.39181237
#   -1.27627565  1.3543418 ]
#  [-0.77161157  0.20335632  0.7597258  -0.01307972  0.88457596 -0.47073943
#    0.88095337 -0.77475003]
#  [-0.84900324  4.93567278 -0.00816303  4.54805768  2.4395424  -0.50420614
#    1.22682431 -1.03886271]]

# %%
#Expectation Maximization:
# A strategy for carrying out maximum likelihood estimation in
# the presence of latent variables is the expectation-maximization algorithm.
# To achieve this, the model is first optimized, then the latent variable values are estimated, 
# and so on until convergence.

# %%
#Importing the necessary libraries
import pandas as pd
import numpy as np
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler

# %%
# Extract features to be used for clustering
X = data.drop([ 'country', 'gdpp'], axis=1)

# Standardize the data
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# Import libraries
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.mixture import GaussianMixture
# from sklearn.cluster import KMeans, GaussianMixture
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
# Fit Expectation Maximization algorithm with 3 clusters
em = GaussianMixture(n_components=3, covariance_type='full', random_state=42)
em.fit(X_std)

# Assign clusters to each data point
data['Cluster'] = em.predict(X_std)

# Print cluster means
print(em.means_)
# Out:
# [[-0.77591111  0.46626279  0.7170653   0.2403168   0.97096299 -0.4725987
#    0.90016842 -0.78942296  1.262295  ]
#  [ 1.32661038 -0.42217389 -0.13954094 -0.15564827 -0.68923797  0.39181237
#   -1.27627565  1.3543418   0.05479966]
#  [-0.33504767 -0.0755976  -0.49267018 -0.08470755 -0.29767044  0.10328209
#    0.19464825 -0.34430102 -1.08914329]]

# %%
#PCA
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from kneed import KneeLocator

# %%
df1 = data.drop(['country'], axis = 1)

# %%
#PCA for Country Dataset

# %%
#PCA for Country Dataset
#importing the necessary libraries
from sklearn.decomposition import PCA
import pandas as pd

# %%
# Load data
data = pd.read_csv("C:\\Users\\n\\Downloads\\Country-data.csv")
# Separate features and labels
X = data.drop(['country'], axis=1)
y = data['country']

# Apply PCA
pca = PCA(n_components=5)
X_pca = pca.fit_transform(X)

# Save PCA results to new CSV file
result = pd.DataFrame(X_pca, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])
result['country'] = y
result.to_csv('Country_data_PCA.csv', index=False)
print(result)
# Out:
#               PC1          PC2        PC3        PC4        PC5  \
# 0   -19815.128018 -1651.124720  38.424930  -0.192311 -13.395274
# 1   -11338.938992  1493.469028 -28.182163 -14.070214  -7.859092
# 2    -8926.352589  3264.684102 -11.916113 -16.804181  12.238446
# 3   -14652.465937  -867.795270  59.558400  40.492538  24.138701
# 4      896.142032  1898.478151 -29.133957   0.507663  -7.630103
# ..            ...          ...        ...        ...        ...
# 162 -17180.967679 -2487.153835 -28.120653   8.630281   3.138299
# 163   -100.445973  -832.252802  -7.709222 -35.835451  32.609135
# 164 -17202.017189  -222.889872 -45.250167  39.915284   8.346047
# 165 -17209.340213  -229.815901   7.958786  -7.521495  12.978900
# 166 -17978.421643 -1163.124631  32.202279   5.350797  12.161930
#
#                  country
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3                 Angola
# 4    Antigua and Barbuda
# ..                   ...
# 162              Vanuatu
# 163            Venezuela
# 164              Vietnam
# 165                Yemen
# 166               Zambia
#
# [167 rows x 6 columns]

# %%
#ICA for Country Dataset

# %%
#Importing the neccessary libraries
from sklearn.decomposition import FastICA
import pandas as pd

# %%
# Load data
# data = pd.read_csv('Country_data.csv')
data = pd.read_csv("C:\\Users\\n\\Downloads\\Country-data.csv")
# Separate features and labels
X = data.drop(['country'], axis=1)
y = data['country']

# Apply ICA
ica = FastICA(n_components=5)
X_ica = ica.fit
print(X_ica )
# Out:
# <bound method FastICA.fit of FastICA(n_components=5)>

# %%
#Randomized Projections for Country Dataset

# %%
#Importing the necessary libraries
from sklearn.random_projection import SparseRandomProjection

# %%
# Load and preprocess the Country dataset
import pandas as pd
from sklearn.preprocessing import StandardScaler

country_data = pd.read_csv("C:\\Users\\n\\Downloads\\Country-data.csv")
X_country = country_data.drop('country', axis=1)
X_country_scaled = StandardScaler().fit_transform(X_country)

# Apply Randomized Projections
from sklearn.random_projection import GaussianRandomProjection

rp = GaussianRandomProjection(n_components=2, random_state=42)
X_country_rp = rp.fit_transform(X_country_scaled)
print(X_country_rp)
# Out:
# [[  0.16179058   0.79406434]
#  [  0.42131249   1.13368098]
#  [ -0.43153969  -0.87020744]
#  [ -0.33518353  -1.10548049]
#  [  0.73342139   0.5552322 ]
#  [ -1.01006615  -1.95490513]
#  [ -0.4179621    1.42219391]
#  [ -0.79255619  -0.97594185]
#  [  0.38497963  -1.29520255]
#  [ -1.87228705  -0.37191298]
#  [ -0.33145661   0.78254177]
#  [ -0.42965095  -1.79594128]
#  [ -1.36687143   1.88682943]
