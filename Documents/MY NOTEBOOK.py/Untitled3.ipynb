# %%
#Importing the necessary Packages in the Jupyter Notebook
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
df = pd.read_csv('C:/Users/n/AppData/Local/Temp/Rar$DIa0.764/Seattle_Police_Department_911_Incident_Response.csv')
# Out:
# C:\Users\n\AppData\Local\Temp\ipykernel_1684\1505666915.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/n/AppData/Local/Temp/Rar$DIa0.764/Seattle_Police_Department_911_Incident_Response.csv')

# %%
df.head()
# Out:
#   CAD CDW ID  CAD Event Number  General Offense Number  Event Clearance Code  \
# 0     ﻿15736       10000246357              2010246357                 242.0
# 1      15737       10000246471              2010246471                  65.0
# 2      15738       10000246255              2010246255                 250.0
# 3      15739       10000246473              2010246473                 460.0
# 4      15740       10000246330              2010246330                 250.0
#
#      Event Clearance Description       Event Clearance SubGroup  \
# 0              FIGHT DISTURBANCE                   DISTURBANCES
# 1          THEFT - MISCELLANEOUS                          THEFT
# 2  MISCHIEF, NUISANCE COMPLAINTS  NUISANCE, MISCHIEF COMPLAINTS
# 3     TRAFFIC (MOVING) VIOLATION          TRAFFIC RELATED CALLS
# 4  MISCHIEF, NUISANCE COMPLAINTS  NUISANCE, MISCHIEF COMPLAINTS
#
#    Event Clearance Group Event Clearance Date  \
# 0           DISTURBANCES      7/17/2010 20:49
# 1         OTHER PROPERTY      7/17/2010 20:50
# 2    NUISANCE, MISCHIEF       7/17/2010 20:55
# 3  TRAFFIC RELATED CALLS      7/17/2010 21:00
# 4    NUISANCE, MISCHIEF       7/17/2010 21:00
#
#               Hundred Block Location District/Sector Zone/Beat  Census Tract  \
# 0               3XX BLOCK OF PINE ST               M        M2     8100.2001
# 1  36XX BLOCK OF DISCOVERY PARK BLVD               Q        Q1     5700.1012
# 2              21XX BLOCK OF 3RD AVE               M        M2     7200.2025
# 3                7XX BLOCK OF ROY ST               D        D1     7200.1002
# 4              9XX BLOCK OF ALOHA ST               D        D1     6700.1009
#
#     Longitude   Latitude               Incident Location  \
# 0 -122.338147  47.610975  (47.610975163, -122.338146748)
# 1 -122.404613  47.658325  (47.658324899, -122.404612874)
# 2 -122.342843  47.613551  (47.613551471, -122.342843234)
# 3 -122.341847  47.625401  (47.625401388, -122.341846999)
# 4 -122.339709  47.627425  (47.627424837, -122.339708605)
#
#   Initial Type Description Initial Type Subgroup Initial Type Group  \
# 0                      NaN                   NaN                NaN
# 1                      NaN                   NaN                NaN
# 2                      NaN                   NaN                NaN
# 3                      NaN                   NaN                NaN
# 4                      NaN                   NaN                NaN
#
#   At Scene Time
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.tail()
# Out:
#         CAD CDW ID  CAD Event Number  General Offense Number  \
# 1048570    1263594       11000021013               201121013
# 1048571    1263595       11000021011               201121011
# 1048572    1263596       11000021010               201121010
# 1048573    1263597       11000021009               201121009
# 1048574    1263599       11000021006               201121006
#
#          Event Clearance Code       Event Clearance Description  \
# 1048570                 100.0  FRAUD (INCLUDING IDENTITY THEFT)
# 1048571                  65.0             THEFT - MISCELLANEOUS
# 1048572                  64.0                          SHOPLIFT
# 1048573                 244.0                 NOISE DISTURBANCE
# 1048574                 430.0            ACCIDENT INVESTIGATION
#
#         Event Clearance SubGroup   Event Clearance Group Event Clearance Date  \
# 1048570              FRAUD CALLS             FRAUD CALLS      1/18/2011 17:46
# 1048571                    THEFT          OTHER PROPERTY      1/18/2011 19:23
# 1048572                    THEFT             SHOPLIFTING      1/18/2011 17:36
# 1048573             DISTURBANCES            DISTURBANCES      1/18/2011 19:31
# 1048574    TRAFFIC RELATED CALLS  ACCIDENT INVESTIGATION      1/18/2011 18:14
#
#                 Hundred Block Location District/Sector Zone/Beat  \
# 1048570          24XX BLOCK OF 4TH AVE               M        M1
# 1048571   18XX BLOCK OF EASTLAKE AVE E               D        D2
# 1048572     24XX BLOCK OF S JACKSON ST               G        G2
# 1048573  12XX BLOCK OF S CLOVERDALE ST               F        F3
# 1048574     2XX BLOCK OF ELLIOTT AVE W               Q        Q3
#
#          Census Tract   Longitude   Latitude               Incident Location  \
# 1048570     7200.2016 -122.345703  47.616414  (47.616414163, -122.345702752)
# 1048571     6600.2001 -122.325401  47.635370  (47.635369535, -122.325400816)
# 1048572     8900.6009 -122.300511  47.599278  (47.599277528, -122.300510574)
# 1048573    11200.3009 -122.316246  47.526445  (47.526444721, -122.316246131)
# 1048574     7100.1016 -122.360486  47.620293  (47.620293019, -122.360485841)
#
#                          Initial Type Description   Initial Type Subgroup  \
# 1048570  SECONDARY - FORGERY/BUNCO/SCAMS/ID THEFT             FRAUD CALLS
# 1048571                         THEFT OF SERVICES          OTHER PROPERTY
# 1048572                          SHOPLIFT - THEFT             SHOPLIFTING
# 1048573          DISTURBANCE, MISCELLANEOUS/OTHER            DISTURBANCES
# 1048574                   TRU - ACC - HIT AND RUN  ACCIDENT INVESTIGATION
#
#             Initial Type Group    At Scene Time
# 1048570            FRAUD CALLS  1/18/2011 17:26
# 1048571                  THEFT  1/18/2011 16:44
# 1048572                  THEFT  1/18/2011 16:49
# 1048573           DISTURBANCES  1/18/2011 16:56
# 1048574  TRAFFIC RELATED CALLS  1/18/2011 17:59

# %%
# select the columns that contain the values of the variables
df = pd.read_csv('C:/Users/n/AppData/Local/Temp/Rar$DIa0.764/Seattle_Police_Department_911_Incident_Response.csv')

subset_data = df[['Initial Type Description', 'Initial Type Group', 'District/Sector', 'Hundred Block Location', 'At Scene Time', 'Event Clearance Date']]

# transform the categorical values into numerical values
subset_data['Initial Type Group'] = subset_data['Initial Type Group'].replace(['DISTURBANCES', 'THEFT', 'NUISANCE, MISCHIEF', 'TRAFFIC RELATED CALLS'], [0, 1, 2, 3])
#Python or R script to generate a subset of the givendata.
# print the subset of the data
print(subset_data)

# %%
#script to count the different values of each relevant variable (column).script to count
#the different values of each relevant  variable (column).script to count the different values of each relevant variable 
#(column).count the different values of each relevant variable

count_initial_type_group = subset_data['Initial Type Group'].value_counts()
count_district_sector = subset_data['District/Sector'].value_counts()
count_at_scene_time = subset_data['At Scene Time'].value_counts()

# generate a histogram for each variable
count_initial_type_group.plot(kind='bar')
plt.title("Initial Type Group")
plt.xlabel("Value")
plt.ylabel("Count")
plt.show()

count_district_sector.plot(kind='bar')
plt.title("District/Sector")
plt.xlabel("Value")
plt.ylabel("Count")
plt.show()

count_at_scene_time.plot(kind='bar')
plt.title("At Scene Time")
plt.xlabel("Value")
plt.ylabel("Count")
plt.show()

# %%
# transform the categorical values into numerical values
subset_data['Initial Type Group'] = subset_data['Initial Type Group'].replace(['DISTURBANCES', 'THEFT', 'NUISANCE, MISCHIEF', 'TRAFFIC RELATED CALLS'], [0, 1, 2, 3])

# generate the statistical descriptions of the variables
desc = subset_data.describe()# transform the categorical values into numerical values
subset_data['Initial Type Group'] = subset_data['Initial Type Group'].replace(['DISTURBANCES', 'THEFT', 'NUISANCE, MISCHIEF', 'TRAFFIC RELATED CALLS'], [0, 1, 2, 3])

# generate the statistical descriptions of the variables
desc = subset_data.describe()# transform the categorical values into numerical values
subset_data['Initial Type Group'] = subset_data['Initial Type Group'].replace(['DISTURBANCES', 'THEFT', 'NUISANCE, MISCHIEF', 'TRAFFIC RELATED CALLS'], [0, 1, 2, 3])

# generate the statistical descriptions of the variables
desc = subset_data.describe()

# %%
# transform the categorical values into numerical values
subset_data['Initial Type Group'] = subset_data['Initial Type Group'].replace(['DISTURBANCES', 'THEFT', 'NUISANCE, MISCHIEF', 'TRAFFIC RELATED CALLS'], [0, 1, 2, 3])

# generate the statistical descriptions of the variables
desc = subset_data.describe()

# %%
sns.lmplot(x='Longitude', y='Latitude', hue='District/Sector', 
           data=df, 
           fit_reg=False, scatter_kws={'alpha':0.1})

# %%
sns.lmplot(x='Longitude', y='Latitude', hue='Zone/Beat', 
           data=df, 
           fit_reg=False, scatter_kws={'alpha':0.1})

# %%
#Seattle Police Department 911 Incident Response Cleaning
df.isna().sum().sort_values()

# %%
def rand_id(x):
    return np.random.randint(100000000, 1000000000, 1)[0]
    
df.loc[df['CAD CDW ID'].isna(),'CAD CDW ID'] = df.loc[df['CAD CDW ID'].isna(),'CAD CDW ID'].apply(rand_id)

# %%
#Data Preparation and Distribution Analysis
df.columns
df.drop(['Initial Type Description', 'Initial Type Subgroup',
       'Initial Type Group', 'At Scene Time'], axis = 1, inplace = True)

# %%
df_copy.drop('address', axis = 1, inplace = True)

# %%
df_copy.to_csv('C:\\Users\\n\\Documents\\Seattle_Police_Department_911_Incident_Response.csv', index=False)
